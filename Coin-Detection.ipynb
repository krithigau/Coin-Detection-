# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Read image
###
#Your Code Here
###
img=cv2.imread("CoinsA.png")

# %%
imageCopy = img.copy()
plt.imshow(img[:,:,::-1]);
plt.title("Original Image")
plt.show()
# Expected output

# %% [markdown]
# # Step 2.1: Convert Image to Grayscale¶

# %%
# Convert image to grayscale
###
### YOUR CODE HERE
###
imageGray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(12,12))
plt.subplot(121);plt.imshow(img[:,:,::-1]);plt.title("Original Image")
plt.subplot(122); plt.imshow(imageGray,cmap='gray');plt.title("Grayscale Image"); plt.show()
# Expected output

# %% [markdown]
# # Step 2.2: Split Image into R,G,B Channels

# %%
# Split cell into channels
# Store them in variables imageB, imageG, imageR
###
### YOUR CODE HERE
###
img_bgr = cv2.imread('CoinsA.png', cv2.IMREAD_COLOR)
imageB, imageG, imageR = cv2.split(img_bgr)

# %%
plt.figure(figsize=(20,10))
plt.subplot(141);plt.imshow(img[:,:,::-1]);plt.title("Original Image")
plt.subplot(142);plt.imshow(imageB,cmap='gray');plt.title("Blue Channel")
plt.subplot(143);plt.imshow(imageG,cmap='gray');plt.title("Green Channel")
plt.subplot(144);plt.imshow(imageR,cmap='gray');plt.title("Red Channel");
plt.show()
# Expected output

# %% [markdown]
# # Step 3.1: Perform Thresholding

# %%
###
### YOUR CODE HERE
###

# %%
# Display the thresholded image
###
### YOUR CODE HERE
###
# Expected output

# %%
thresh=20
maxValue=255
th,dst_bin_inv=cv2.threshold(imageG,thresh,maxValue,cv2.THRESH_BINARY_INV)

# %%
plt.imshow(dst_bin_inv, cmap='gray',vmin=0,vmax=255)
plt.title("Threhold binary")
plt.show()

# %% [markdown]
# # Step 3.2: Perform morphological operations

# %%
###
### YOUR CODE HERE
###

# %%
kSize=(5,5)
kernel2=cv2.getStructuringElement(cv2.MORPH_ELLIPSE,kSize)

# %%
imageDialated2=cv2.dilate(dst_bin_inv,kernel2,iterations=2)

# %%
###
### YOUR CODE HERE
###
plt.imshow(imageDialated2,cmap='gray');plt.title('Dilated Image Iteration 2');plt.show()
# Expected output

# %%
kSize=(11,11)
kernel1=cv2.getStructuringElement(cv2.MORPH_ELLIPSE,kSize)
imageEroded=cv2.erode(imageDialated2,kernel1)

# %%
plt.imshow(imageEroded,cmap='gray');plt.title("Eroded Image");plt.show()

# %%
# Display all the images
# you have obtained in the intermediate steps
###
### YOUR CODE HERE
###

# %%
# Get structuring element/kernel which will be used for dilation
###
### YOUR CODE HERE
###

# %%
###
### YOUR CODE HERE
###
plt.imshow(imageEroded,cmap='gray');plt.title("Eroded Image");plt.show()
# Expected output

# %%
###
### YOUR CODE HERE
###

# %% [markdown]
# # Step 4.1: Create SimpleBlobDetector

# %%
# Set up the SimpleBlobdetector with default parameters.
params = cv2.SimpleBlobDetector_Params()

params.blobColor = 0

params.minDistBetweenBlobs = 2

# Filter by Area.
params.filterByArea = False

# Filter by Circularity
params.filterByCircularity = True
params.minCircularity = 0.8

# Filter by Convexity
params.filterByConvexity = True
params.minConvexity = 0.8

# Filter by Inertia
params.filterByInertia =True
params.minInertiaRatio = 0.8

# %%
# Create SimpleBlobDetector
detector = cv2.SimpleBlobDetector_create(params)

# %% [markdown]
# # Step 4.2: Detect Coins

# %%
# Detect blobs
###
### YOUR CODE HERE
###
keypoints = detector.detect(imageEroded)

# %%
# Print number of coins detected
###
### YOUR CODE HERE
###
print(f"Number of coins detected: {len(keypoints)}")
# Out:
# Number of coins detected: 9

# %%
# Display the final image
###
### YOUR CODE HERE
###
# Expected output
